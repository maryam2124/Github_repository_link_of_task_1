# %%
from IPython.display import Image, display

display(Image("/content/tdddddddddddd.png"))

# %%
from IPython.display import Image, display

display(Image("/content/Screenshot 2026-05-05 111502.png"))

# %%
display(Image("/content/Screenshot 2026-05-05 123524.png"))

# %%
display(Image("/content/abcccccccccccccccccccc.png"))

# %%
response = {
    # greetings
    "hello": "Hi! How can I help you?",
    "hi": "Hello! What can I do for you?",
    "hey": "Hey there!",
    "good morning": "Good morning!",
    "good night": "Good night!",
    "good evening": "Good evening!",
    "howdy": "Howdy! How are you?",

    # small talk
    "how are you": "I'm just code, but I'm functioning well!",
    "what's up": "Just processing data!",
    "how is it going": "Everything is running smoothly!",
    "are you fine": "Yes, I am fully functional!",
    "are you okay": "I am operating normally!",

    # identity
    "who are you": "I am a rule-based AI chatbot.",
    "what is your name": "I am your assistant chatbot.",
    "what can you do": "I can answer simple predefined questions.",
    "what are you": "I am a chatbot created using Python logic.",

    # help
    "help": "Ask me simple questions like greetings or info.",
    "commands": "Try: hello, bye, help, who are you",
    "menu": "You can ask about AI, Python, or greetings.",
    "options": "Try asking: hello, what is ai, tell me a joke",

    # AI / knowledge
    "what is ai": "AI means Artificial Intelligence.",
    "what is python": "Python is a programming language.",
    "what is data science": "It is the study of data and insights.",
    "what is machine learning": "It is a subset of AI that learns from data.",
    "what is programming": "Programming is writing instructions for computers.",

    # education
    "what is computer": "A computer is an electronic device that processes data.",
    "what is internet": "The internet is a global network of computers.",
    "what is code": "Code is a set of instructions written for a computer.",

    # fun
    "tell me a joke": "Why did the computer get cold? It left its Windows open!",
    "make me laugh": "Why don’t programmers like nature? Too many bugs!",
    "are you human": "No, I am a chatbot.",
    "do you sleep": "I don’t sleep, I run on code!",

    # interaction
    "thank you": "You're welcome!",
    "thanks": "Glad I could help!",
    "nice": "Thank you!",
    "okay": "Alright!",

    # time/date
    "time": "I cannot fetch real-time data yet.",
    "date": "I cannot access live date data.",
    "what day is it": "I cannot access system date yet.",

    # system
    "exit": "Chat ended.",
    "bye": "Goodbye! See you next time.",
    "quit": "Exiting chatbot. Take care!"
}

# %%
display(Image("/content/cddddddddddddd.png"))

# %%
user_name = input("Enter your name:\n").upper()
# Out:
# Enter your name:
# Maryamkhan

# %%
display(Image("/content/dffffffffffffffffffffffff.png"))

# %%
print("\n==============================")
print("WELCOME DEAR:", user_name)
print("How can I help you?")
print("==============================")

while True:

    user_input = input("You: ").lower().strip()

    if user_input == "exit" or user_input == "bye":
        print(response["bye"])
        break

    found = False
    for key in response:
        if key == user_input:
            print(response[key])
            found = True
            break

    if not found:
        print("I don't understand that. Try something else.")
# Out:
# ...
# WELCOME DEAR: MARYAMKHAN
# How can I help you?
# ...
# You: hello
# Hi! How can I help you?
# You: what is you name
# I don't understand that. Try something else.
# You: do you sleep
# I don’t sleep, I run on code!
# You: make me laugh
# Why don’t programmers like nature? Too many bugs!
# You: thanks
# Glad I could help!
# You: bye
# Goodbye! See you next time.
